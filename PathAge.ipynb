# %% [markdown]
# # Predicting healthy-aging signatures from human metabolite data

# %%
# Import libraries
import pandas

# %%
# Load data
filePath = "/home/user/Downloads/metabol.xlsx"
data = pandas.read_excel(filePath)
data.head(10)
# Out:
#    Remnant_Cholesterol  VLDL_Cholesterol  Clinical_LDL_Cholesterol  \
# 0               1.7702           0.76556                    3.0117
# 1               0.9748           0.57336                    1.2569
# 2               1.6066           1.06900                    1.8803
# 3               1.3499           0.65451                    2.4337
# 4               1.0770           0.37042                    1.4251
# 5               1.1691           0.44917                    2.0539
# 6               1.3423           0.65120                    2.1282
# 7               1.9432           0.99295                    3.5243
# 8               1.1004           0.41962                    2.0290
# 9               1.7636           0.66389                    2.8065
#
#    LDL_Cholesterol  HDL_Cholesterol  Triglycerides_in_VLDL  \
# 0           1.9554          1.28070                0.75324
# 1           1.0009          0.70050                1.31950
# ...

# %% [markdown]
# The dataset contains **139 columns (predictors)** and **81,651 rows (samples)**. The last two columns have been created by Maria and contain a numeric signature (score) that expresses healthy aging.
